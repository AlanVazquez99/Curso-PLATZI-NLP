# %%
import nltk

nltk.download('book')
from nltk.book import *

from collections import Counter
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\alanv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package abc is already up-to-date!
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\alanv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\alanv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package chat80 is already up-to-date!
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\alanv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package cmudict is already up-to-date!
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\alanv\AppData\Roaming\nltk_data...
# [nltk_data]    |   Package conll2000 is already up-to-date!
# [nltk_data]    | Downloading package conll2002 to
# ...

# %%
txt = text9
s_txt = sorted(txt)

# %%
# %%timeit
FreqDist(txt)
# Out:
# 82.6 ms ± 9.19 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
Counter(txt)
# Out:
# 25 ms ± 5.24 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
FreqDist(s_txt)
# Out:
# 73.1 ms ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
Counter(s_txt)
# Out:
# 13.1 ms ± 783 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
import re

# %%
texts = [ i for i in dir(nltk.book) if re.search(r'text\d', i)]
for text in texts:
    print(text)
    exec(compile(f'print({text}, "\\n", len({text}), "\\n" )', 
        '', 'exec'))
# Out:
# text1
# <Text: Moby Dick by Herman Melville 1851>
#  260819
#
# text2
# <Text: Sense and Sensibility by Jane Austen 1811>
#  141576
#
# text3
# <Text: The Book of Genesis>
#  44764
#
# text4
# <Text: Inaugural Address Corpus>
#  149797
#
# text5
# <Text: Chat Corpus>
#  45010
#
# text6
# <Text: Monty Python and the Holy Grail>
#  16967
#
# text7
# <Text: Wall Street Journal>
#  100676
#
# text8
# <Text: Personals Corpus>
#  4867
#
# text9
# <Text: The Man Who Was Thursday by G . K . Chesterton 1908>
#  69213

# %%
counter_time = [103, 60, 16, 60, 13, 7, 40, 2, 21]
counter_sort_time = [61, 33, 6, 39, 6, 1, 20, .5, 11]

fdist_time = [354, 158, 60, 232, 73, 20, 125, 7, 73]
fdist_sort_time = [243, 135, 48, 164, 50, 13, 93, 4, 68]

# %%
import pandas as pd

# %%
df = pd.DataFrame([counter_time, counter_sort_time, fdist_time, fdist_sort_time], 
    columns=['text1', 'text2', 'text3', 'text4', 'text5', 'text6', 'text7', 'text8','text9'],
    index=['counter', 'counter_sorted', 'fdist', 'fdist_sorted'])

df
# Out:
#                 text1  text2  text3  text4  text5  text6  text7  text8  text9
# counter           103     60     16     60     13      7     40    2.0     21
# counter_sorted     61     33      6     39      6      1     20    0.5     11
# fdist             354    158     60    232     73     20    125    7.0     73
# fdist_sorted      243    135     48    164     50     13     93    4.0     68

# %%
df = df.T
df['len'] = [260819, 141576, 44764, 149797, 45010, 16967, 100676, 4867, 69213]
df
# Out:
#        counter  counter_sorted  fdist  fdist_sorted     len
# text1    103.0            61.0  354.0         243.0  260819
# text2     60.0            33.0  158.0         135.0  141576
# text3     16.0             6.0   60.0          48.0   44764
# text4     60.0            39.0  232.0         164.0  149797
# text5     13.0             6.0   73.0          50.0   45010
# text6      7.0             1.0   20.0          13.0   16967
# text7     40.0            20.0  125.0          93.0  100676
# text8      2.0             0.5    7.0           4.0    4867
# text9     21.0            11.0   73.0          68.0   69213

# %%
print(dir(Counter))
# Out:
# ['__add__', '__and__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__le__', '__len__', '__lt__', '__missing__', '__module__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__weakref__', '_keep_positive', 'clear', 'copy', 'elements', 'fromkeys', 'get', 'items', 'keys', 'most_common', 'pop', 'popitem', 'setdefault', 'subtract', 'update', 'values']

# %%
print(dir(FreqDist))
# Out:
# ['B', 'N', 'Nr', '__add__', '__and__', '__class__', '__contains__', '__delattr__', '__delitem__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__gt__', '__hash__', '__iadd__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__le__', '__len__', '__lt__', '__missing__', '__module__', '__ne__', '__neg__', '__new__', '__or__', '__pos__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__unicode__', '__weakref__', '_cumulative_frequencies', '_keep_positive', 'clear', 'copy', 'elements', 'freq', 'fromkeys', 'get', 'hapaxes', 'items', 'keys', 'max', 'most_common', 'pformat', 'plot', 'pop', 'popitem', 'pprint', 'r_Nr', 'setdefault', 'subtract', 'tabulate', 'unicode_repr', 'update', 'values']
